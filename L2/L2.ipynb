# %%
import pandas as pd
import numpy as np

# %%
a = pd.Series([2,5,7,8,43], index=["popa", "jopa", "pizdec", "huy", "pizda"])
a
# Out:
# popa       2
# jopa       5
# pizdec     7
# huy        8
# pizda     43
# dtype: int64

# %%
a.index
# Out:
# Index(['popa', 'jopa', 'pizdec', 'huy', 'pizda'], dtype='object')

# %%
a.values
# Out:
# array([ 2,  5,  7,  8, 43], dtype=int64)

# %%
a[3]
# Out:
# 8

# %%
df = pd.DataFrame({
    'Age': [46, 37, 44, 42, 42],
    'Country': ['Spain', 'Spain', 'Germany', 'Germany', 'France'],
    'Gender': ['Female', 'Female', 'Male', 'Male', 'Male']
})

df
# Out:
#    Age  Country  Gender
# 0   46    Spain  Female
# 1   37    Spain  Female
# 2   44  Germany    Male
# 3   42  Germany    Male
# 4   42   France    Male

# %%
df['Age']
# Out:
# 0    46
# 1    37
# 2    44
# 3    42
# 4    42
# Name: Age, dtype: int64

# %%
df.Country
# Out:
# 0      Spain
# 1      Spain
# 2    Germany
# 3    Germany
# 4     France
# Name: Country, dtype: object

# %%
df = pd.read_csv('./extra/Churn_Modelling.csv')
df
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0          2       0.00              1          1               1
# 1          1   83807.86              1          0               1
# 2          8  159660.80              3          1               0
# 3          1       0.00              2          0               0
# 4          2  125510.82              1          1               1
# ...      ...        ...            ...        ...             ...
# 9995       5       0.00              2          1               0
# 9996      10   57369.61              1          1               1
# 9997       7       0.00              1          0               1
# 9998       3   75075.31              2          1               0
# 9999       4  130142.79              1          1               0
#
#       EstimatedSalary  Exited
# 0           101348.88       1
# 1           112542.58       0
# 2           113931.57       1
# 3            93826.63       0
# 4            79084.10       0
# ...               ...     ...
# 9995         96270.64       0
# 9996        101699.77       0
# 9997         42085.58       1
# 9998         92888.52       1
# 9999         38190.78       0
#
# [10000 rows x 14 columns]

# %%
df.sample(frac=0.5)
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 6665       6666    15599024       Hope          506     Spain    Male   32
# 7471       7472    15721569   Chialuka          658   Germany  Female   55
# 6885       6886    15606849   Blackall          698    France  Female   27
# 4111       4112    15705034       Peng          691     Spain    Male   40
# 5159       5160    15651103        Sal          762     Spain  Female   69
# ...         ...         ...        ...          ...       ...     ...  ...
# 2476       2477    15617136   Mazzanti          451   Germany  Female   38
# 4766       4767    15719858       Chao          659     Spain  Female   38
# 6449       6450    15625706      White          693   Germany    Male   45
# 4856       4857    15721921  Woolnough          796    France    Male   44
# 6697       6698    15655389     Leckie          638    France    Male   41
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 6665       8       0.00              2          0               1
# 7471       8  119327.93              1          0               1
# 6885       1   94920.71              1          1               1
# 4111       1       0.00              2          1               1
# 5159       9  183744.98              1          1               1
# ...      ...        ...            ...        ...             ...
# 2476       9   61482.47              1          1               1
# 4766       9       0.00              2          1               1
# 6449       2  116546.59              2          0               0
# 4856       8  165326.20              1          1               1
# 6697       1  131762.94              1          1               1
#
#       EstimatedSalary  Exited
# 6665        182692.80       0
# 7471        119439.66       0
# 6885         40339.90       0
# 4111        145613.17       0
# 5159        196993.69       0
# ...               ...     ...
# 2476        167538.66       0
# 4766         35701.06       0
# 6449         23140.28       1
# 4856         57205.55       0
# 6697         47675.29       0
#
# [5000 rows x 14 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Gender           10000 non-null  object
#  6   Age              10000 non-null  int64
#  7   Tenure           10000 non-null  int64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(2), int64(9), object(3)
# memory usage: 1.1+ MB

# %%
df['Age'].dtype
# Out:
# dtype('int64')

# %%
df['HasCrCard'] = df['HasCrCard'].astype('bool')

# %%
df['HasCrCard'].dtype
# Out:
# dtype('bool')
